# %% [markdown]
# <a href="https://colab.research.google.com/github/SDASPb/HomeWorkSBp/blob/main/lession%E2%84%963.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
df = pd.read_excel('Default.xlsx')
df.head()

sns.regplot(x='balance', y='income', data=df)
plt.show()

from scipy import stats
print("Коэффициент корреляции Пирсона и значение p-уровня значимости:")
pearson_coef, p_value = stats.pearsonr(data['income'], data['balance']) #находим коэффициент корреляции Пирсона и значение p-уровня значимости между признаками 'income' и 'balance' в датасете 'data'.
print("Коэффициент корреляции Пирсона:", pearson_coef)
print("Значение p-уровня значимости:", p_value)
sns.scatterplot(data=data, y='income', x = "balance") #Вывод графика 
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Коэффициент корреляции Пирсона и значение p-уровня значимости:
# Коэффициент корреляции Пирсона: -0.15224340058606678
# Значение p-уровня значимости: 6.380440181539541e-53
